# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# CHAPTER **2**

# %% [markdown]
# Exercise 1

# %%
name = input('Enter Your Name:') # input of variable name to hold the users input.
print('Hello', name)#python will read the data from the user using the input() function. The function calls the variable name.
# Out:
# Enter Your Name:james
# Hello james

# %% [markdown]
# Enter your name: Chuck
# Hello Chuck

# %% [markdown]
# Exercise 2

# %%
hrs = input('Enter Hours:')#input of variable name that will hold the users input
rate = input ('Enter Rate:')#input of variable name that will hold the users input
pay = float(hrs)*float(rate)#multiply the users input in hrs and rate to get the result
print(pay)# The function calls the variable name "pay".
# Out:
# Enter Hours:8
# Enter Rate:104
# 832.0

# %% [markdown]
# Enter Hours: 35
# Enter Rate: 2.75
# Pay: 96.25

# %% [markdown]
# Exercise 3

# %%
width = 17 #set the width in 17
height = 12.0 #set the height in 17

value1 = width//2  #assigns the result of the integer division (//) operation between width and 2 to a variable called value1.
print(f"Expression 1: {value1} ({type(value1)})") # used to display the value of value1 and its type. The f before the string allows the use of curly braces {} to insert the value of value1 into the string.

value2 = width/2.0 #assigns the result of the integer division (/) operation between width and 2 to a variable called value2.
print(f"Expression 2: {value2} ({type(value2)})")# used to display the value of value2 and its type. The f before the string allows the use of curly braces {} to insert the value of value2 into the string.

value3 = height/3 #assigns the result of the integer division (/) operation between height and 2 to a variable called value3.
print(f"Expression 3: {value3} ({type(value3)})") # used to display the value of value3 and its type. The f before the string allows the use of curly braces {} to insert the value of value3 into the string.

value4 = 1 + 2 * 5 # performs a mathematical operation to calculate the result, which is then assigned to a variable called value4.
print(f"Expression 4: {value4} ({type(value4)})") # used to display the value of value4 and its type. The f before the string allows the use of curly braces {} to insert the value of value4 into the string.
# Out:
# Expression 1: 8 (<class 'int'>)
# Expression 2: 8.5 (<class 'float'>)
# Expression 3: 4.0 (<class 'float'>)
# Expression 4: 11 (<class 'int'>)

# %% [markdown]
# width = 17
# height = 12.0

# %% [markdown]
# Exercise 4
#
# Write a program that uses input to prompt a user for a number and then outputs the square of the number

# %%
number = int(input("Enter a number: "))
square = number ** 2
print(f"The square of {number} is {square}")
# Out:
# Enter a number: 3
# The square of 3 is 9

# %% [markdown]
# Enter a number: 3
#
# The square of 3 is 9

# %% [markdown]
# CHALLENGE

# %%
celsius = float(input("Enter the temperature in Celsius: "))   # Get the Celsius temperature from the user
fahrenheit = (celsius * 9/5) + 32                              # Convert Celsius to Fahrenheit
print(f"The temperature in Fahrenheit is: {fahrenheit:.2f}°F") # Print the converted temperature
