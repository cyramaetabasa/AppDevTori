# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %% [markdown]
# EXERCISES NO.1

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# The error for this line of code is the print which is big letter P, to correct the code it should change into small letter p: like 'print'.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# The error for this code is missing open parentheses.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# The error for this code is missing single quotation.

# %%
print('Hello world!')
# Out:
# Hello world!

# %% [markdown]
# The error for this code is the double single quotation.

# %% [markdown]
# Exercise No.2
#
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)

# %% [markdown]
# The output for this code is 44

# %% [markdown]
# Exercise 3
#
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)

# %% [markdown]
# The error for this code name 'X' is not defined. It should replace the x with the X in the line x = 43 replace the 'x' with the 'X' to get the correct result.
