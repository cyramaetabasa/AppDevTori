# %% [markdown]
# ####Exercise 1

# %% [markdown]
# Given the code below
#
# text = 'Business Analytics'
# What will the following expressions produce?
#
# text[4]
# text[2:4]
# text[:4]
# text[4:]
# text[-2]
# text[-4:-2]
# text[-2:]
# text[:-2]

# %%
text = 'Business Analytics'

print(text[4])
print(text[2:4])
print(text[:4])
print(text[4:])
print(text[-2])
print(text[-4:-2])
print(text[-2:])
print(text[:-2])
# Out:
# n
# si
# Busi
# ness Analytics
# c
# ti
# cs
# Business Analyti

# %% [markdown]
# ####Exercise 2

# %% [markdown]
# Given the code below:
#
# phrase = 'One Ring to rule them all'
# What string slicing expression gives out the following words:
#
# 'One '
# 'Ring'
# 'all'
# 'them'
# 'One Ring to rule them all'

# %%
phrase = 'One Ring to rule them all'

print(phrase[:4])
print(phrase[4:8])
print(phrase[-3:])
print(phrase[17:21])
print(phrase[:])
# Out:
# One
# Ring
# all
# them
# One Ring to rule them all

# %% [markdown]
# ####CHALLENGE

# %% [markdown]
# Write a program which repeatedly reads a full name, then does the following:
#
# *strips the name of any trailing spaces
# *capitalizes the first letter
# *puts the rest into smaller *letters*

# %%
while True:
    full_name = input("Enter a full name (or type 'exit' to quit): ")

    if full_name.lower() == 'exit':
        print("Exiting program...")
        break
    cleanedname = full_name.strip().capitalize()
    cleanedname = cleanedname[:1] + cleanedname[1:].lower()

    print("Cleaned name:", cleanedname)
# Out:
# Enter a full name (or type 'exit' to quit): quit
# Cleaned name: Quit
# Enter a full name (or type 'exit' to quit): exit
# Exiting program...
