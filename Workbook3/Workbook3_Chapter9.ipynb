# %% [markdown]
# ####Exercise 1
# Create a dictionary with the following keys and values showing a partial list of Real GDP growth in Annual percent change from IMF (Source: http://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD)
#
# China 6.5
# Japan 0.7
# Philippines 6.7
# United States 2.3

# %%
# dictionary with Real GDP growth data
gdp_growth = {
    'China': 6.5,
    'Japan': 0.7,
    'Philippines': 6.7,
    'United States': 2.3
}

# print the dictionary
print(gdp_growth)
# Out:
# {'China': 6.5, 'Japan': 0.7, 'Philippines': 6.7, 'United States': 2.3}

# %% [markdown]
# #### Exercise 2
#
# ```Display all the keys and values from the dictionary you created above```

# %%
# Create a dictionary with Real GDP growth data
gdp_growth = {
    'China': 6.5,
    'Japan': 0.7,
    'Philippines': 6.7,
    'United States': 2.3
}

# Display all keys and values from the dictionary
for country, growth_rate in gdp_growth.items():
    print(country, "-", growth_rate)
# Out:
# China - 6.5
# Japan - 0.7
# Philippines - 6.7
# United States - 2.3

# %% [markdown]
# #### Exercise 3
#
# Write a program that asks the user to enter a line of text and then counts the number of each word that appeared in the line of text.
# Use the string function `split()` to make a list of words from a given string
# e.g.:

# %%
# user to enter a line of text
line = input("Enter a line of text: ")

# Split the word
word_list = line.split()

# dictionary to store word counts
word_counts = {}

# Counts the number of each word
for word in word_list:
    if word in word_counts:
        word_counts[word] += 1
    else:
        word_counts[word] = 1

# Display the result
print("Word counts:")
for word, count in word_counts.items():
    print(word + ":", count)
# Out:
# Enter a line of text: tami-ya
# Word counts:
# tami-ya: 1
